# %% [markdown]
# A two-dimensional model with periodic boundary conditions. Radial distribution function.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Arrangement of particles on the lattice and RDF for density 0.7.

# %%
data07 = pd.read_csv('/Users/bartlomiejkos/Documents/Programming/C++/Wprowadzenie do C++/Symulacj komputerowe w fizyce/RDF_3rd/data07.csv', header=None, names=('x','y'))
rdf07 = pd.read_csv('/Users/bartlomiejkos/Documents/Programming/C++/Wprowadzenie do C++/Symulacj komputerowe w fizyce/RDF_3rd/RDFdata07.csv', header=None, names=('rw', 'rdf'))
divider = int(len(data07) / 2)
rdfdivider = int(len(rdf07) / 2)
#plt.figure(figsize=(6,6))
plt.figure(figsize=(20, 10))
plt.subplot(1,2,1)
plt.scatter(data07['x'][:divider:1], data07['y'][:divider:1], s=200, label='initial', c='r', alpha=0.7)
plt.scatter(data07['x'][divider::1], data07['y'][divider::1], s=200, label='final', c='g', alpha=0.7)
plt.xlim(0,10)
plt.ylim(0,10)
plt.xlabel('x [$\sigma$]')
plt.ylabel('y [$\sigma$]')
plt.legend()
plt.title(r'$\rho$' "= 0.7")
plt.subplot(1,2,2)
plt.scatter(rdf07['rw'][rdfdivider::], rdf07['rdf'][rdfdivider::])
plt.plot(rdf07['rw'][rdfdivider::], rdf07['rdf'][rdfdivider::], c='g')
plt.ylabel('g(r)')
plt.xlabel(r'$r / \sigma$')
plt.title('RDF for 'r'$\rho$' "= 0.7")
plt.grid()
plt.show()

# %% [markdown]
# Arrangement of particles on the lattice and RDF for density 0.8.

# %%
data08 = pd.read_csv('/Users/bartlomiejkos/Documents/Programming/C++/Wprowadzenie do C++/Symulacj komputerowe w fizyce/RDF_3rd/data08.csv', header=None, names=('x','y'))
rdf08 = pd.read_csv('/Users/bartlomiejkos/Documents/Programming/C++/Wprowadzenie do C++/Symulacj komputerowe w fizyce/RDF_3rd/RDFdata08.csv', header=None, names=('rw', 'rdf'))
divider = int(len(data08) / 2)
rdfdivider = int(len(rdf08) / 2)
#plt.figure(figsize=(6,6))
plt.figure(figsize=(20, 10))
plt.subplot(1,2,1)
plt.scatter(data08['x'][:divider:1], data08['y'][:divider:1], s=200, label='initial', c='r', alpha=0.7)
plt.scatter(data08['x'][divider::1], data08['y'][divider::1], s=200, label='final', c='y', alpha=0.7)
plt.xlim(0,10)
plt.ylim(0,10)
plt.xlabel('x [$\sigma$]')
plt.ylabel('y [$\sigma$]')
plt.legend()
plt.title(r'$\rho$' "= 0.8")
plt.subplot(1,2,2)
plt.scatter(rdf08['rw'][rdfdivider::], rdf08['rdf'][rdfdivider::])
plt.plot(rdf08['rw'][rdfdivider::], rdf08['rdf'][rdfdivider::], c='y')
plt.ylabel('g(r)')
plt.xlabel(r'$r / \sigma$')
plt.title('RDF for 'r'$\rho$' "= 0.8")
plt.grid()
plt.show()

# %% [markdown]
# Arrangement of particles on the lattice and RDF for density 0.85.

# %%
data085 = pd.read_csv('/Users/bartlomiejkos/Documents/Programming/C++/Wprowadzenie do C++/Symulacj komputerowe w fizyce/RDF_3rd/data085.csv', header=None, names=('x','y'))
rdf085 = pd.read_csv('/Users/bartlomiejkos/Documents/Programming/C++/Wprowadzenie do C++/Symulacj komputerowe w fizyce/RDF_3rd/RDFdata085.csv', header=None, names=('rw', 'rdf'))
divider = int(len(data085) / 2)
rdfdivider = int(len(rdf085) / 2)
#plt.figure(figsize=(6,6))
plt.figure(figsize=(20, 10))
plt.subplot(1,2,1)
plt.scatter(data085['x'][:divider:1], data085['y'][:divider:1], s=200, label='initial', c='r', alpha=0.7)
plt.scatter(data085['x'][divider::1], data085['y'][divider::1], s=200, label='final', c='m', alpha=0.7)
plt.xlim(0,10)
plt.ylim(0,10)
plt.xlabel('x [$\sigma$]')
plt.ylabel('y [$\sigma$]')
plt.legend()
plt.title(r'$\rho$' "= 0.85")
plt.subplot(1,2,2)
plt.scatter(rdf085['rw'][rdfdivider::], rdf085['rdf'][rdfdivider::])
plt.plot(rdf085['rw'][rdfdivider::], rdf085['rdf'][rdfdivider::], c='m')
plt.ylabel('g(r)')
plt.xlabel(r'$r / \sigma$')
plt.title('RDF for 'r'$\rho$' "= 0.85")
plt.grid()
plt.show()

# %% [markdown]
# Arrangement of particles on the lattice and RDF for density 0.9.

# %%
data09 = pd.read_csv('/Users/bartlomiejkos/Documents/Programming/C++/Wprowadzenie do C++/Symulacj komputerowe w fizyce/RDF_3rd/data09.csv', header=None, names=('x','y'))
rdf09 = pd.read_csv('/Users/bartlomiejkos/Documents/Programming/C++/Wprowadzenie do C++/Symulacj komputerowe w fizyce/RDF_3rd/RDFdata09.csv', header=None, names=('rw', 'rdf'))
divider = int(len(data085) / 2)
rdfdivider = int(len(rdf085) / 2)
#plt.figure(figsize=(6,6))
plt.figure(figsize=(20, 10))
plt.subplot(1,2,1)
plt.scatter(data09['x'][:divider:1], data09['y'][:divider:1], s=200, label='initial', c='r', alpha=0.7)
plt.scatter(data09['x'][divider::1], data09['y'][divider::1], s=200, label='final', c='b', alpha=0.7)
plt.xlim(0,10)
plt.ylim(0,10)
plt.xlabel('x [$\sigma$]')
plt.ylabel('y [$\sigma$]')
plt.legend()
plt.title(r'$\rho$' "= 0.9")
plt.subplot(1,2,2)
plt.scatter(rdf09['rw'][rdfdivider::], rdf09['rdf'][rdfdivider::])
plt.plot(rdf09['rw'][rdfdivider::], rdf09['rdf'][rdfdivider::], c='b')
plt.ylabel('g(r)')
plt.xlabel(r'$r / \sigma$')
plt.title('RDF for 'r'$\rho$' "= 0.9")
plt.grid()
plt.show()

# %% [markdown]
# Radial density functions for different densities of particles.

# %%
plt.figure(figsize=(12,8))
plt.plot(rdf07['rw'][391::2], rdf07['rdf'][391::2], c='g', label=r'$\rho$' "= 0.7")
plt.plot(rdf08['rw'][391::2], rdf08['rdf'][391::2], c='m', label=r'$\rho$' "= 0.8")
plt.plot(rdf085['rw'][391::2], rdf085['rdf'][391::2], c='y', label=r'$\rho$' "= 0.85")
plt.plot(rdf09['rw'][391::2], rdf09['rdf'][391::2], c='b', label=r'$\rho$' "= 0.9")
plt.ylabel('g(r)')
plt.xlabel(r'$r / \sigma$')
plt.title('RDF for different 'r'$\rho$')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Radial density functions for initial setup.

# %%
plt.figure(figsize=(12,8))
plt.plot(rdf07['rw'][:391:2], rdf07['rdf'][:391:2], c='g', label=r'$\rho$' "= 0.7")
plt.plot(rdf08['rw'][:391:2], rdf08['rdf'][:391:2], c='m', label=r'$\rho$' "= 0.8")
plt.plot(rdf085['rw'][:391:2], rdf085['rdf'][:391:2], c='y', label=r'$\rho$' "= 0.85")
plt.plot(rdf09['rw'][:391:2], rdf09['rdf'][:391:2], c='b', label=r'$\rho$' "= 0.9")
plt.ylabel('g(r)')
plt.xlabel(r'$r / \sigma$')
plt.title('RDF for different 'r'$\rho$ - initial setup')
plt.legend()
plt.grid()
plt.show()
